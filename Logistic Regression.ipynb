# %%
import pandas as pd
from math import exp
from random import seed
from random import randrange

# %%
def evaluate_algorithm(dataset, algorithm, n_folds, *args):
	folds = cross_validation_split(dataset, n_folds) # Splits Dataset
	scores = list() 
    # cross validation (folds) times
	for fold in folds:
		train_set = list(folds)
		train_set.remove(fold)
		train_set = sum(train_set, [])
		test_set = list()
		for row in fold:
			row_copy = list(row)
			test_set.append(row_copy)
			row_copy[-1] = None
		predicted = algorithm(train_set, test_set, *args)
		actual = [row[-1] for row in fold]
		accuracy = accuracy_metric(actual, predicted)
		scores.append(accuracy)
	return scores

# %% [markdown]
# # Logistic Regression

# %%
def logistic_regression(train, test, l_rate, n_epoch):
	predictions = list()
	coef = coefficients_sgd(train, l_rate, n_epoch)
	for row in test:
		yhat = predict(row, coef)
		yhat = round(yhat)
		predictions.append(yhat)
	return(predictions)

# %% [markdown]
# # Cross Validation Split

# %%
# Splits dataset into n_folds 
def cross_validation_split(dataset, n_folds):
	dataset_split = list()
	dataset_copy = list(dataset)
	fold_size = int(len(dataset) / n_folds)
	for i in range(n_folds):
		fold = list()
		while len(fold) < fold_size:
			index = randrange(len(dataset_copy))
			fold.append(dataset_copy.pop(index))
		dataset_split.append(fold)
	return dataset_split

# %% [markdown]
# # Coefficient Learning (SGD)

# %%
# Estimate logistic regression coefficients using stochastic gradient descent
def coefficients_sgd(train, l_rate, n_epoch):
	coef = [0.0 for i in range(len(train[0]))]
	for epoch in range(n_epoch):
		sum_error = 0
		for row in train:
			yhat = predict(row, coef)
			error = row[-1] - yhat
			sum_error += error**2
			coef[0] = coef[0] + l_rate * error * yhat * (1.0 - yhat)
			for i in range(len(row)-1):
				coef[i + 1] = coef[i + 1] + l_rate * error * yhat * (1.0 - yhat) * row[i]
		print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
	return coef

# %% [markdown]
# # Predictions with Learned Coefficients

# %%
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	return 1.0 / (1.0 + exp(-yhat))

# %%
# Calculate accuracy percentage
def accuracy_metric(actual, predicted):
	correct = 0
	for i in range(len(actual)):
		if actual[i] == predicted[i]:
			correct += 1
	return correct / float(len(actual)) * 100.0

# %%
seed(1)
filename = pd.read_csv('diabetes.csv')
n_folds = 5
l_rate = 0.1
n_epoch = 100
scores = evaluate_algorithm(dataset,logistic_regression,n_folds,l_rate,n_epoch)
print('Scores: %s' % scores)
print('Mean Accuracy: %.3f%%' % (sum(scores)/float(len(scores))))
# Out:
# >epoch=0, lrate=0.100, error=1.705
# >epoch=1, lrate=0.100, error=1.383
# >epoch=2, lrate=0.100, error=1.264
# >epoch=3, lrate=0.100, error=1.166
# >epoch=4, lrate=0.100, error=1.079
# >epoch=5, lrate=0.100, error=1.001
# >epoch=6, lrate=0.100, error=0.930
# >epoch=7, lrate=0.100, error=0.865
# >epoch=8, lrate=0.100, error=0.807
# >epoch=9, lrate=0.100, error=0.755
# >epoch=10, lrate=0.100, error=0.707
# >epoch=11, lrate=0.100, error=0.664
# >epoch=12, lrate=0.100, error=0.624
# >epoch=13, lrate=0.100, error=0.589
# >epoch=14, lrate=0.100, error=0.556
# >epoch=15, lrate=0.100, error=0.527
# >epoch=16, lrate=0.100, error=0.499
# >epoch=17, lrate=0.100, error=0.475
# >epoch=18, lrate=0.100, error=0.452
# >epoch=19, lrate=0.100, error=0.431
# >epoch=20, lrate=0.100, error=0.411
# >epoch=21, lrate=0.100, error=0.393
# >epoch=22, lrate=0.100, error=0.377
# >epoch=23, lrate=0.100, error=0.361
# >epoch=24, lrate=0.100, error=0.347
# >epoch=25, lrate=0.100, error=0.334
# >epoch=26, lrate=0.100, error=0.321
# >epoch=27, lrate=0.100, error=0.309
# >epoch=28, lrate=0.100, error=0.299
# >epoch=29, lrate=0.100, error=0.288
# >epoch=30, lrate=0.100, error=0.279
# >epoch=31, lrate=0.100, error=0.270
# >epoch=32, lrate=0.100, error=0.261
# >epoch=33, lrate=0.100, error=0.253
# >epoch=34, lrate=0.100, error=0.245
# >epoch=35, lrate=0.100, error=0.238
# >epoch=36, lrate=0.100, error=0.231
# >epoch=37, lrate=0.100, error=0.225
# >epoch=38, lrate=0.100, error=0.219
# >epoch=39, lrate=0.100, error=0.213
# >epoch=40, lrate=0.100, error=0.207
# >epoch=41, lrate=0.100, error=0.202
# >epoch=42, lrate=0.100, error=0.197
# >epoch=43, lrate=0.100, error=0.192
# >epoch=44, lrate=0.100, error=0.188
# >epoch=45, lrate=0.100, error=0.183
# >epoch=46, lrate=0.100, error=0.179
# >epoch=47, lrate=0.100, error=0.175
# >epoch=48, lrate=0.100, error=0.171
# >epoch=49, lrate=0.100, error=0.167
# >epoch=50, lrate=0.100, error=0.164
# >epoch=51, lrate=0.100, error=0.160
# >epoch=52, lrate=0.100, error=0.157
# >epoch=53, lrate=0.100, error=0.154
# >epoch=54, lrate=0.100, error=0.151
# >epoch=55, lrate=0.100, error=0.148
# >epoch=56, lrate=0.100, error=0.145
# >epoch=57, lrate=0.100, error=0.142
# >epoch=58, lrate=0.100, error=0.140
# >epoch=59, lrate=0.100, error=0.137
# >epoch=60, lrate=0.100, error=0.135
# >epoch=61, lrate=0.100, error=0.132
# >epoch=62, lrate=0.100, error=0.130
# >epoch=63, lrate=0.100, error=0.128
# >epoch=64, lrate=0.100, error=0.126
# >epoch=65, lrate=0.100, error=0.124
# >epoch=66, lrate=0.100, error=0.122
# >epoch=67, lrate=0.100, error=0.120
# >epoch=68, lrate=0.100, error=0.118
# >epoch=69, lrate=0.100, error=0.116
# >epoch=70, lrate=0.100, error=0.114
# >epoch=71, lrate=0.100, error=0.112
# >epoch=72, lrate=0.100, error=0.111
# >epoch=73, lrate=0.100, error=0.109
# >epoch=74, lrate=0.100, error=0.107
# >epoch=75, lrate=0.100, error=0.106
# >epoch=76, lrate=0.100, error=0.104
# >epoch=77, lrate=0.100, error=0.103
# >epoch=78, lrate=0.100, error=0.102
# >epoch=79, lrate=0.100, error=0.100
# >epoch=80, lrate=0.100, error=0.099
# >epoch=81, lrate=0.100, error=0.097
# >epoch=82, lrate=0.100, error=0.096
# >epoch=83, lrate=0.100, error=0.095
# >epoch=84, lrate=0.100, error=0.094
# >epoch=85, lrate=0.100, error=0.092
# >epoch=86, lrate=0.100, error=0.091
# >epoch=87, lrate=0.100, error=0.090
# >epoch=88, lrate=0.100, error=0.089
# >epoch=89, lrate=0.100, error=0.088
# >epoch=90, lrate=0.100, error=0.087
# >epoch=91, lrate=0.100, error=0.086
# >epoch=92, lrate=0.100, error=0.085
# >epoch=93, lrate=0.100, error=0.084
# >epoch=94, lrate=0.100, error=0.083
# >epoch=95, lrate=0.100, error=0.082
# >epoch=96, lrate=0.100, error=0.081
# >epoch=97, lrate=0.100, error=0.080
# >epoch=98, lrate=0.100, error=0.079
# >epoch=99, lrate=0.100, error=0.078
# >epoch=0, lrate=0.100, error=1.856
# >epoch=1, lrate=0.100, error=1.420
# >epoch=2, lrate=0.100, error=1.178
# >epoch=3, lrate=0.100, error=0.999
# >epoch=4, lrate=0.100, error=0.863
# >epoch=5, lrate=0.100, error=0.758
# >epoch=6, lrate=0.100, error=0.674
# >epoch=7, lrate=0.100, error=0.607
# >epoch=8, lrate=0.100, error=0.551
# >epoch=9, lrate=0.100, error=0.504
# >epoch=10, lrate=0.100, error=0.464
# >epoch=11, lrate=0.100, error=0.429
# >epoch=12, lrate=0.100, error=0.400
# >epoch=13, lrate=0.100, error=0.374
# >epoch=14, lrate=0.100, error=0.351
# >epoch=15, lrate=0.100, error=0.330
# >epoch=16, lrate=0.100, error=0.312
# >epoch=17, lrate=0.100, error=0.295
# >epoch=18, lrate=0.100, error=0.280
# >epoch=19, lrate=0.100, error=0.267
# >epoch=20, lrate=0.100, error=0.255
# >epoch=21, lrate=0.100, error=0.243
# >epoch=22, lrate=0.100, error=0.233
# >epoch=23, lrate=0.100, error=0.224
# >epoch=24, lrate=0.100, error=0.215
# >epoch=25, lrate=0.100, error=0.207
# >epoch=26, lrate=0.100, error=0.199
# >epoch=27, lrate=0.100, error=0.192
# >epoch=28, lrate=0.100, error=0.185
# >epoch=29, lrate=0.100, error=0.179
# >epoch=30, lrate=0.100, error=0.173
# >epoch=31, lrate=0.100, error=0.168
# >epoch=32, lrate=0.100, error=0.163
# >epoch=33, lrate=0.100, error=0.158
# >epoch=34, lrate=0.100, error=0.154
# >epoch=35, lrate=0.100, error=0.149
# >epoch=36, lrate=0.100, error=0.145
# >epoch=37, lrate=0.100, error=0.141
# >epoch=38, lrate=0.100, error=0.138
# >epoch=39, lrate=0.100, error=0.134
# >epoch=40, lrate=0.100, error=0.131
# >epoch=41, lrate=0.100, error=0.128
# >epoch=42, lrate=0.100, error=0.125
# >epoch=43, lrate=0.100, error=0.122
# >epoch=44, lrate=0.100, error=0.119
# >epoch=45, lrate=0.100, error=0.116
# >epoch=46, lrate=0.100, error=0.114
# >epoch=47, lrate=0.100, error=0.111
# >epoch=48, lrate=0.100, error=0.109
# >epoch=49, lrate=0.100, error=0.107
# >epoch=50, lrate=0.100, error=0.105
# >epoch=51, lrate=0.100, error=0.103
# >epoch=52, lrate=0.100, error=0.101
# >epoch=53, lrate=0.100, error=0.099
# >epoch=54, lrate=0.100, error=0.097
# >epoch=55, lrate=0.100, error=0.095
# >epoch=56, lrate=0.100, error=0.094
# >epoch=57, lrate=0.100, error=0.092
# >epoch=58, lrate=0.100, error=0.090
# >epoch=59, lrate=0.100, error=0.089
# >epoch=60, lrate=0.100, error=0.087
# >epoch=61, lrate=0.100, error=0.086
# >epoch=62, lrate=0.100, error=0.084
# >epoch=63, lrate=0.100, error=0.083
# >epoch=64, lrate=0.100, error=0.082
# >epoch=65, lrate=0.100, error=0.080
# >epoch=66, lrate=0.100, error=0.079
# >epoch=67, lrate=0.100, error=0.078
# >epoch=68, lrate=0.100, error=0.077
# >epoch=69, lrate=0.100, error=0.076
# >epoch=70, lrate=0.100, error=0.075
# >epoch=71, lrate=0.100, error=0.074
# >epoch=72, lrate=0.100, error=0.073
# >epoch=73, lrate=0.100, error=0.072
# >epoch=74, lrate=0.100, error=0.071
# >epoch=75, lrate=0.100, error=0.070
# >epoch=76, lrate=0.100, error=0.069
# >epoch=77, lrate=0.100, error=0.068
# >epoch=78, lrate=0.100, error=0.067
# >epoch=79, lrate=0.100, error=0.066
# >epoch=80, lrate=0.100, error=0.065
# >epoch=81, lrate=0.100, error=0.064
# >epoch=82, lrate=0.100, error=0.064
# >epoch=83, lrate=0.100, error=0.063
# >epoch=84, lrate=0.100, error=0.062
# >epoch=85, lrate=0.100, error=0.061
# >epoch=86, lrate=0.100, error=0.061
# >epoch=87, lrate=0.100, error=0.060
# >epoch=88, lrate=0.100, error=0.059
# >epoch=89, lrate=0.100, error=0.058
# >epoch=90, lrate=0.100, error=0.058
# >epoch=91, lrate=0.100, error=0.057
# >epoch=92, lrate=0.100, error=0.057
# >epoch=93, lrate=0.100, error=0.056
# >epoch=94, lrate=0.100, error=0.055
# >epoch=95, lrate=0.100, error=0.055
# >epoch=96, lrate=0.100, error=0.054
# >epoch=97, lrate=0.100, error=0.054
# >epoch=98, lrate=0.100, error=0.053
# >epoch=99, lrate=0.100, error=0.052
# >epoch=0, lrate=0.100, error=2.185
# >epoch=1, lrate=0.100, error=1.864
# >epoch=2, lrate=0.100, error=1.609
# >epoch=3, lrate=0.100, error=1.397
# >epoch=4, lrate=0.100, error=1.225
# >epoch=5, lrate=0.100, error=1.083
# >epoch=6, lrate=0.100, error=0.967
# >epoch=7, lrate=0.100, error=0.870
# >epoch=8, lrate=0.100, error=0.790
# >epoch=9, lrate=0.100, error=0.721
# >epoch=10, lrate=0.100, error=0.663
# >epoch=11, lrate=0.100, error=0.613
# >epoch=12, lrate=0.100, error=0.569
# >epoch=13, lrate=0.100, error=0.531
# >epoch=14, lrate=0.100, error=0.497
# >epoch=15, lrate=0.100, error=0.467
# >epoch=16, lrate=0.100, error=0.440
# >epoch=17, lrate=0.100, error=0.416
# >epoch=18, lrate=0.100, error=0.394
# >epoch=19, lrate=0.100, error=0.375
# >epoch=20, lrate=0.100, error=0.357
# >epoch=21, lrate=0.100, error=0.341
# >epoch=22, lrate=0.100, error=0.326
# >epoch=23, lrate=0.100, error=0.312
# >epoch=24, lrate=0.100, error=0.299
# >epoch=25, lrate=0.100, error=0.288
# >epoch=26, lrate=0.100, error=0.277
# >epoch=27, lrate=0.100, error=0.267
# >epoch=28, lrate=0.100, error=0.257
# >epoch=29, lrate=0.100, error=0.248
# >epoch=30, lrate=0.100, error=0.240
# >epoch=31, lrate=0.100, error=0.232
# >epoch=32, lrate=0.100, error=0.225
# >epoch=33, lrate=0.100, error=0.218
# >epoch=34, lrate=0.100, error=0.212
# >epoch=35, lrate=0.100, error=0.206
# >epoch=36, lrate=0.100, error=0.200
# >epoch=37, lrate=0.100, error=0.194
# >epoch=38, lrate=0.100, error=0.189
# >epoch=39, lrate=0.100, error=0.184
# >epoch=40, lrate=0.100, error=0.180
# >epoch=41, lrate=0.100, error=0.175
# >epoch=42, lrate=0.100, error=0.171
# >epoch=43, lrate=0.100, error=0.167
# >epoch=44, lrate=0.100, error=0.163
# >epoch=45, lrate=0.100, error=0.159
# >epoch=46, lrate=0.100, error=0.156
# >epoch=47, lrate=0.100, error=0.153
# >epoch=48, lrate=0.100, error=0.149
# >epoch=49, lrate=0.100, error=0.146
# >epoch=50, lrate=0.100, error=0.143
# >epoch=51, lrate=0.100, error=0.140
# >epoch=52, lrate=0.100, error=0.138
# >epoch=53, lrate=0.100, error=0.135
# >epoch=54, lrate=0.100, error=0.132
# >epoch=55, lrate=0.100, error=0.130
# >epoch=56, lrate=0.100, error=0.127
# >epoch=57, lrate=0.100, error=0.125
# >epoch=58, lrate=0.100, error=0.123
# >epoch=59, lrate=0.100, error=0.121
# >epoch=60, lrate=0.100, error=0.119
# >epoch=61, lrate=0.100, error=0.117
# >epoch=62, lrate=0.100, error=0.115
# >epoch=63, lrate=0.100, error=0.113
# >epoch=64, lrate=0.100, error=0.111
# >epoch=65, lrate=0.100, error=0.109
# >epoch=66, lrate=0.100, error=0.108
# >epoch=67, lrate=0.100, error=0.106
# >epoch=68, lrate=0.100, error=0.104
# >epoch=69, lrate=0.100, error=0.103
# >epoch=70, lrate=0.100, error=0.101
# >epoch=71, lrate=0.100, error=0.100
# >epoch=72, lrate=0.100, error=0.098
# >epoch=73, lrate=0.100, error=0.097
# >epoch=74, lrate=0.100, error=0.096
# >epoch=75, lrate=0.100, error=0.094
# >epoch=76, lrate=0.100, error=0.093
# >epoch=77, lrate=0.100, error=0.092
# >epoch=78, lrate=0.100, error=0.091
# >epoch=79, lrate=0.100, error=0.089
# >epoch=80, lrate=0.100, error=0.088
# >epoch=81, lrate=0.100, error=0.087
# >epoch=82, lrate=0.100, error=0.086
# >epoch=83, lrate=0.100, error=0.085
# >epoch=84, lrate=0.100, error=0.084
# >epoch=85, lrate=0.100, error=0.083
# >epoch=86, lrate=0.100, error=0.082
# >epoch=87, lrate=0.100, error=0.081
# >epoch=88, lrate=0.100, error=0.080
# >epoch=89, lrate=0.100, error=0.079
# >epoch=90, lrate=0.100, error=0.078
# >epoch=91, lrate=0.100, error=0.077
# >epoch=92, lrate=0.100, error=0.076
# >epoch=93, lrate=0.100, error=0.076
# >epoch=94, lrate=0.100, error=0.075
# >epoch=95, lrate=0.100, error=0.074
# >epoch=96, lrate=0.100, error=0.073
# >epoch=97, lrate=0.100, error=0.072
# >epoch=98, lrate=0.100, error=0.072
# >epoch=99, lrate=0.100, error=0.071
# >epoch=0, lrate=0.100, error=2.054
# >epoch=1, lrate=0.100, error=1.595
# >epoch=2, lrate=0.100, error=1.307
# >epoch=3, lrate=0.100, error=1.109
# >epoch=4, lrate=0.100, error=0.966
# >epoch=5, lrate=0.100, error=0.857
# >epoch=6, lrate=0.100, error=0.770
# >epoch=7, lrate=0.100, error=0.700
# >epoch=8, lrate=0.100, error=0.642
# >epoch=9, lrate=0.100, error=0.593
# >epoch=10, lrate=0.100, error=0.551
# >epoch=11, lrate=0.100, error=0.515
# >epoch=12, lrate=0.100, error=0.483
# >epoch=13, lrate=0.100, error=0.455
# >epoch=14, lrate=0.100, error=0.430
# >epoch=15, lrate=0.100, error=0.407
# >epoch=16, lrate=0.100, error=0.387
# >epoch=17, lrate=0.100, error=0.369
# >epoch=18, lrate=0.100, error=0.352
# >epoch=19, lrate=0.100, error=0.337
# >epoch=20, lrate=0.100, error=0.323
# >epoch=21, lrate=0.100, error=0.310
# >epoch=22, lrate=0.100, error=0.298
# >epoch=23, lrate=0.100, error=0.287
# >epoch=24, lrate=0.100, error=0.277
# >epoch=25, lrate=0.100, error=0.267
# >epoch=26, lrate=0.100, error=0.258
# >epoch=27, lrate=0.100, error=0.250
# >epoch=28, lrate=0.100, error=0.242
# >epoch=29, lrate=0.100, error=0.235
# >epoch=30, lrate=0.100, error=0.228
# >epoch=31, lrate=0.100, error=0.221
# >epoch=32, lrate=0.100, error=0.215
# >epoch=33, lrate=0.100, error=0.209
# >epoch=34, lrate=0.100, error=0.203
# >epoch=35, lrate=0.100, error=0.198
# >epoch=36, lrate=0.100, error=0.193
# >epoch=37, lrate=0.100, error=0.188
# >epoch=38, lrate=0.100, error=0.184
# >epoch=39, lrate=0.100, error=0.179
# >epoch=40, lrate=0.100, error=0.175
# >epoch=41, lrate=0.100, error=0.171
# >epoch=42, lrate=0.100, error=0.167
# >epoch=43, lrate=0.100, error=0.164
# >epoch=44, lrate=0.100, error=0.160
# >epoch=45, lrate=0.100, error=0.157
# >epoch=46, lrate=0.100, error=0.154
# >epoch=47, lrate=0.100, error=0.151
# >epoch=48, lrate=0.100, error=0.148
# >epoch=49, lrate=0.100, error=0.145
# >epoch=50, lrate=0.100, error=0.142
# >epoch=51, lrate=0.100, error=0.139
# >epoch=52, lrate=0.100, error=0.137
# >epoch=53, lrate=0.100, error=0.134
# >epoch=54, lrate=0.100, error=0.132
# >epoch=55, lrate=0.100, error=0.130
# >epoch=56, lrate=0.100, error=0.128
# >epoch=57, lrate=0.100, error=0.125
# >epoch=58, lrate=0.100, error=0.123
# >epoch=59, lrate=0.100, error=0.121
# >epoch=60, lrate=0.100, error=0.119
# >epoch=61, lrate=0.100, error=0.117
# >epoch=62, lrate=0.100, error=0.116
# >epoch=63, lrate=0.100, error=0.114
# >epoch=64, lrate=0.100, error=0.112
# >epoch=65, lrate=0.100, error=0.110
# >epoch=66, lrate=0.100, error=0.109
# >epoch=67, lrate=0.100, error=0.107
# >epoch=68, lrate=0.100, error=0.106
# >epoch=69, lrate=0.100, error=0.104
# >epoch=70, lrate=0.100, error=0.103
# >epoch=71, lrate=0.100, error=0.101
# >epoch=72, lrate=0.100, error=0.100
# >epoch=73, lrate=0.100, error=0.099
# >epoch=74, lrate=0.100, error=0.097
# >epoch=75, lrate=0.100, error=0.096
# >epoch=76, lrate=0.100, error=0.095
# >epoch=77, lrate=0.100, error=0.094
# >epoch=78, lrate=0.100, error=0.092
# >epoch=79, lrate=0.100, error=0.091
# >epoch=80, lrate=0.100, error=0.090
# >epoch=81, lrate=0.100, error=0.089
# >epoch=82, lrate=0.100, error=0.088
# >epoch=83, lrate=0.100, error=0.087
# >epoch=84, lrate=0.100, error=0.086
# >epoch=85, lrate=0.100, error=0.085
# >epoch=86, lrate=0.100, error=0.084
# >epoch=87, lrate=0.100, error=0.083
# >epoch=88, lrate=0.100, error=0.082
# >epoch=89, lrate=0.100, error=0.081
# >epoch=90, lrate=0.100, error=0.080
# >epoch=91, lrate=0.100, error=0.079
# >epoch=92, lrate=0.100, error=0.078
# >epoch=93, lrate=0.100, error=0.078
# >epoch=94, lrate=0.100, error=0.077
# >epoch=95, lrate=0.100, error=0.076
# >epoch=96, lrate=0.100, error=0.075
# >epoch=97, lrate=0.100, error=0.074
# >epoch=98, lrate=0.100, error=0.074
# >epoch=99, lrate=0.100, error=0.073
# >epoch=0, lrate=0.100, error=1.622
# >epoch=1, lrate=0.100, error=1.337
# >epoch=2, lrate=0.100, error=1.179
# >epoch=3, lrate=0.100, error=1.030
# >epoch=4, lrate=0.100, error=0.904
# >epoch=5, lrate=0.100, error=0.800
# >epoch=6, lrate=0.100, error=0.715
# >epoch=7, lrate=0.100, error=0.646
# >epoch=8, lrate=0.100, error=0.588
# >epoch=9, lrate=0.100, error=0.540
# >epoch=10, lrate=0.100, error=0.499
# >epoch=11, lrate=0.100, error=0.464
# >epoch=12, lrate=0.100, error=0.434
# >epoch=13, lrate=0.100, error=0.408
# >epoch=14, lrate=0.100, error=0.384
# >epoch=15, lrate=0.100, error=0.364
# >epoch=16, lrate=0.100, error=0.346
# >epoch=17, lrate=0.100, error=0.329
# >epoch=18, lrate=0.100, error=0.314
# >epoch=19, lrate=0.100, error=0.301
# >epoch=20, lrate=0.100, error=0.288
# >epoch=21, lrate=0.100, error=0.277
# >epoch=22, lrate=0.100, error=0.266
# >epoch=23, lrate=0.100, error=0.257
# >epoch=24, lrate=0.100, error=0.248
# >epoch=25, lrate=0.100, error=0.240
# >epoch=26, lrate=0.100, error=0.232
# >epoch=27, lrate=0.100, error=0.225
# >epoch=28, lrate=0.100, error=0.218
# >epoch=29, lrate=0.100, error=0.211
# >epoch=30, lrate=0.100, error=0.205
# >epoch=31, lrate=0.100, error=0.200
# >epoch=32, lrate=0.100, error=0.194
# >epoch=33, lrate=0.100, error=0.189
# >epoch=34, lrate=0.100, error=0.185
# >epoch=35, lrate=0.100, error=0.180
# >epoch=36, lrate=0.100, error=0.176
# >epoch=37, lrate=0.100, error=0.172
# >epoch=38, lrate=0.100, error=0.168
# >epoch=39, lrate=0.100, error=0.164
# >epoch=40, lrate=0.100, error=0.161
# >epoch=41, lrate=0.100, error=0.157
# >epoch=42, lrate=0.100, error=0.154
# >epoch=43, lrate=0.100, error=0.151
# >epoch=44, lrate=0.100, error=0.148
# >epoch=45, lrate=0.100, error=0.145
# >epoch=46, lrate=0.100, error=0.142
# >epoch=47, lrate=0.100, error=0.140
# >epoch=48, lrate=0.100, error=0.137
# >epoch=49, lrate=0.100, error=0.135
# >epoch=50, lrate=0.100, error=0.132
# >epoch=51, lrate=0.100, error=0.130
# >epoch=52, lrate=0.100, error=0.128
# >epoch=53, lrate=0.100, error=0.126
# >epoch=54, lrate=0.100, error=0.123
# >epoch=55, lrate=0.100, error=0.121
# >epoch=56, lrate=0.100, error=0.120
# >epoch=57, lrate=0.100, error=0.118
# >epoch=58, lrate=0.100, error=0.116
# >epoch=59, lrate=0.100, error=0.114
# >epoch=60, lrate=0.100, error=0.112
# >epoch=61, lrate=0.100, error=0.111
# >epoch=62, lrate=0.100, error=0.109
# >epoch=63, lrate=0.100, error=0.108
# >epoch=64, lrate=0.100, error=0.106
# >epoch=65, lrate=0.100, error=0.105
# >epoch=66, lrate=0.100, error=0.103
# >epoch=67, lrate=0.100, error=0.102
# >epoch=68, lrate=0.100, error=0.100
# >epoch=69, lrate=0.100, error=0.099
# >epoch=70, lrate=0.100, error=0.098
# >epoch=71, lrate=0.100, error=0.097
# >epoch=72, lrate=0.100, error=0.095
# >epoch=73, lrate=0.100, error=0.094
# >epoch=74, lrate=0.100, error=0.093
# >epoch=75, lrate=0.100, error=0.092
# >epoch=76, lrate=0.100, error=0.091
# >epoch=77, lrate=0.100, error=0.090
# >epoch=78, lrate=0.100, error=0.089
# >epoch=79, lrate=0.100, error=0.088
# >epoch=80, lrate=0.100, error=0.087
# >epoch=81, lrate=0.100, error=0.086
# >epoch=82, lrate=0.100, error=0.085
# >epoch=83, lrate=0.100, error=0.084
# >epoch=84, lrate=0.100, error=0.083
# >epoch=85, lrate=0.100, error=0.082
# >epoch=86, lrate=0.100, error=0.081
# >epoch=87, lrate=0.100, error=0.080
# >epoch=88, lrate=0.100, error=0.079
# >epoch=89, lrate=0.100, error=0.079
# >epoch=90, lrate=0.100, error=0.078
# >epoch=91, lrate=0.100, error=0.077
# >epoch=92, lrate=0.100, error=0.076
# >epoch=93, lrate=0.100, error=0.075
# >epoch=94, lrate=0.100, error=0.075
# >epoch=95, lrate=0.100, error=0.074
# >epoch=96, lrate=0.100, error=0.073
# >epoch=97, lrate=0.100, error=0.073
# >epoch=98, lrate=0.100, error=0.072
# >epoch=99, lrate=0.100, error=0.071
# Scores: [100.0, 100.0, 100.0, 100.0, 100.0]
# Mean Accuracy: 100.000%
